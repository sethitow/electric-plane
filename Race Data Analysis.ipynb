# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
# filename = r'China 2018 Telemetry Data/F11-Telemetry-181113-030957.flt Summary V8.3g.xlsx'
filename = r'China 2018 Telemetry Data/F11-Telemetry-181115-073107.flt Summary V8.3g.xlsx'

df = pd.read_excel(filename,
                   sheet_name='Data',
                   usecols='A:B,BW,DW:EH,FD,FO:FU,GE:GK,GM:GN')

# %%
df
# Out:
#       EIS Time(sec)  EIS RPM  RaceSpeed(mph)  GPS Msg Time  GPS Time  \
# 0               NaN      NaN             NaN             0   73331.4
# 1               0.0      NaN             NaN             1   73332.4
# 2               0.0      NaN             NaN             2   73333.4
# 3               0.0      NaN             NaN             3   73334.4
# 4               0.0      NaN             NaN             4   73335.4
# 5               0.0      NaN             NaN             5   73336.4
# 6               0.0      NaN             NaN             6   73337.4
# 7               0.0      NaN             NaN             7   73338.4
# 8               0.0      NaN             NaN             8   73339.4
# 9               0.0      NaN             NaN             9   73340.4
# 10              0.0      NaN             NaN            10   73341.4
# 11              0.0      NaN             NaN            11   73342.4
# 12              0.0      NaN             NaN            12   73343.4
# ...

# %%
df.columns
# Out:
# Index(['EIS Time(sec)', 'EIS RPM', 'RaceSpeed(mph)', 'GPS Msg Time',
#        'GPS Time', 'GPS Alt(Kft)', 'Lat', 'Long', 'Course', 'Gnd Speed(kts)',
#        'Date', 'HDOP', 'Quality', 'Satellites', 'GPSTemp', 'Abs Start Time',
#        'GPS Alt(ft)', 'GPSLatDegrees', 'GPSLatMinutes', 'GPSLongDegrees',
#        'GPSLongMinutes', 'FlightTime', 'EngineTime', 'LapNum', 'LapTime',
#        'LapSpeed(mph)', 'TurnRate', 'DeltaAlt', 'Long Min', 'Lat Min',
#        'NextPylon', 'PylonDist'],
#       dtype='object')

# %%
plt.plot(df['Lat'], df['Long'])

# %%
plt.plot(df['GPS Time'], df['Gnd Speed(kts)']*1.15078)
